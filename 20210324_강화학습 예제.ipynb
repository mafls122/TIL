# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

import tensorflow as tf
from tensorflow import keras

# Common imports
import numpy as np
import os

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# To get smooth animations
import matplotlib.animation as animation
mpl.rc('animation', html='jshtml')

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "rl"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %% [markdown]
# # Introduction to OpenAI gym

# %% [markdown]
# In this notebook we will be using [OpenAI gym](https://gym.openai.com/), a great toolkit for developing and comparing Reinforcement Learning algorithms. It provides many environments for your learning *agents* to interact with. Let's start by importing `gym`:

# %%
import gym

# %%
def plot_environment(env, figsize=(5,4)):
    plt.figure(figsize=figsize)
    img = env.render(mode="rgb_array")
    plt.imshow(img)
    plt.axis("off")
    return img
def update_scene(num, frames, patch):
    patch.set_data(frames[num])
    return patch,

def plot_animation(frames, repeat=False, interval=40):
    fig = plt.figure()
    patch = plt.imshow(frames[0])
    plt.axis('off')
    anim = animation.FuncAnimation(
        fig, update_scene, fargs=(frames, patch),
        frames=len(frames), repeat=repeat, interval=interval)
    plt.close()
    return anim

# %% [markdown]
# # Neural Network Policies

# %%
import sys
import gym
import pylab
import random
import numpy as np
from collections import deque
from keras.layers import Dense
from keras.optimizers import Adam
from keras.models import Sequential

EPISODES = 300


# 카트폴 예제에서의 DQN 에이전트
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.render = False
        self.load_model = False

        # 상태와 행동의 크기 정의
        self.state_size = state_size
        self.action_size = action_size

        # DQN 하이퍼파라미터
        self.discount_factor = 0.99
        self.learning_rate = 0.001
        self.epsilon = 1.0
        self.epsilon_decay = 0.999
        self.epsilon_min = 0.01
        self.batch_size = 64
        self.train_start = 1000

        # 리플레이 메모리, 최대 크기 2000
        self.memory = deque(maxlen=2000)

        # 모델과 타깃 모델 생성
        self.model = self.build_model()
        self.target_model = self.build_model()

        # 타깃 모델 초기화
        self.update_target_model()

        if self.load_model:
            self.model.load_weights("./save_model/cartpole_dqn_trained.h5")

    # 상태가 입력, 큐함수가 출력인 인공신경망 생성
    def build_model(self):
        model = Sequential()
        model.add(Dense(24, input_dim=self.state_size, activation='relu',
                        kernel_initializer='he_uniform'))
        model.add(Dense(24, activation='relu',
                        kernel_initializer='he_uniform'))
        model.add(Dense(self.action_size, activation='linear',
                        kernel_initializer='he_uniform'))
        model.summary()
        model.compile(loss='mse', optimizer=Adam(lr=self.learning_rate))
        return model

    # 타깃 모델을 모델의 가중치로 업데이트
    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())

    # 입실론 탐욕 정책으로 행동 선택
    def get_action(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        else:
            q_value = self.model.predict(state)
            return np.argmax(q_value[0])

    # 샘플 <s, a, r, s'>을 리플레이 메모리에 저장
    def append_sample(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    # 리플레이 메모리에서 무작위로 추출한 배치로 모델 학습
    def train_model(self):
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

        # 메모리에서 배치 크기만큼 무작위로 샘플 추출
        mini_batch = random.sample(self.memory, self.batch_size)

        states = np.zeros((self.batch_size, self.state_size))
        next_states = np.zeros((self.batch_size, self.state_size))
        actions, rewards, dones = [], [], []

        for i in range(self.batch_size):
            states[i] = mini_batch[i][0]
            actions.append(mini_batch[i][1])
            rewards.append(mini_batch[i][2])
            next_states[i] = mini_batch[i][3]
            dones.append(mini_batch[i][4])

        # 현재 상태에 대한 모델의 큐함수
        # 다음 상태에 대한 타깃 모델의 큐함수
        target = self.model.predict(states)
        target_val = self.target_model.predict(next_states)

        # 벨만 최적 방정식을 이용한 업데이트 타깃
        for i in range(self.batch_size):
            if dones[i]:
                target[i][actions[i]] = rewards[i]
            else:
                target[i][actions[i]] = rewards[i] + self.discount_factor * (
                    np.amax(target_val[i]))

        self.model.fit(states, target, batch_size=self.batch_size,
                       epochs=1, verbose=0)

# %%
def main():
    # CartPole-v1 환경, 최대 타임스텝 수가 500
    env = gym.make('CartPole-v1')
    state_size = env.observation_space.shape[0]
    action_size = env.action_space.n

    # DQN 에이전트 생성
    agent = DQNAgent(state_size, action_size)

    scores, episodes = [], []

    for e in range(EPISODES):
        done = False
        score = 0
        # env 초기화
        state = env.reset()
        state = np.reshape(state, [1, state_size])

        while not done:
            if agent.render:
                env.render()

            # 현재 상태로 행동을 선택
            action = agent.get_action(state)
            # 선택한 행동으로 환경에서 한 타임스텝 진행
            next_state, reward, done, info = env.step(action)
            next_state = np.reshape(next_state, [1, state_size])
            # 에피소드가 중간에 끝나면 -100 보상
            reward = reward if not done or score == 499 else -100

            # 리플레이 메모리에 샘플 <s, a, r, s'> 저장
            agent.append_sample(state, action, reward, next_state, done)
            # 매 타임스텝마다 학습
            if len(agent.memory) >= agent.train_start:
                agent.train_model()

            score += reward
            state = next_state

            if done:
                # 각 에피소드마다 타깃 모델을 모델의 가중치로 업데이트
                agent.update_target_model()

                score = score if score == 500 else score + 100
                # 에피소드마다 학습 결과 출력
                scores.append(score)
                episodes.append(e)
                #pylab.plot(episodes, scores, 'b')
                pylab.savefig("cartpole_dqn.png")
                print("episode:", e, "  score:", score, "  memory length:",
                      len(agent.memory), "  epsilon:", agent.epsilon)

                # 이전 10개 에피소드의 점수 평균이 490보다 크면 학습 중단
                if np.mean(scores[-min(10, len(scores)):]) > 490:
                    agent.model.save_weights("cartpole_dqn.h5")
                    return agent.model

# %%
model = main()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 24)                120
# _________________________________________________________________
# dense_13 (Dense)             (None, 24)                600
# _________________________________________________________________
# dense_14 (Dense)             (None, 2)                 50
# =================================================================
# Total params: 770
# Trainable params: 770
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 24)                120
# _________________________________________________________________
# dense_16 (Dense)             (None, 24)                600
# _________________________________________________________________
# dense_17 (Dense)             (None, 2)                 50
# =================================================================
# Total params: 770
# Trainable params: 770
# Non-trainable params: 0
# _________________________________________________________________
# episode: 0   score: 10.0   memory length: 11   epsilon: 1.0
# episode: 1   score: 34.0   memory length: 46   epsilon: 1.0
# episode: 2   score: 14.0   memory length: 61   epsilon: 1.0
# episode: 3   score: 10.0   memory length: 72   epsilon: 1.0
# episode: 4   score: 19.0   memory length: 92   epsilon: 1.0
# episode: 5   score: 56.0   memory length: 149   epsilon: 1.0
# episode: 6   score: 21.0   memory length: 171   epsilon: 1.0
# episode: 7   score: 26.0   memory length: 198   epsilon: 1.0
# episode: 8   score: 15.0   memory length: 214   epsilon: 1.0
# episode: 9   score: 38.0   memory length: 253   epsilon: 1.0
# episode: 10   score: 19.0   memory length: 273   epsilon: 1.0
# episode: 11   score: 29.0   memory length: 303   epsilon: 1.0
# episode: 12   score: 25.0   memory length: 329   epsilon: 1.0
# episode: 13   score: 9.0   memory length: 339   epsilon: 1.0
# episode: 14   score: 55.0   memory length: 395   epsilon: 1.0
# episode: 15   score: 21.0   memory length: 417   epsilon: 1.0
# episode: 16   score: 11.0   memory length: 429   epsilon: 1.0
# episode: 17   score: 26.0   memory length: 456   epsilon: 1.0
# episode: 18   score: 22.0   memory length: 479   epsilon: 1.0
# episode: 19   score: 15.0   memory length: 495   epsilon: 1.0
# episode: 20   score: 15.0   memory length: 511   epsilon: 1.0
# episode: 21   score: 11.0   memory length: 523   epsilon: 1.0
# episode: 22   score: 13.0   memory length: 537   epsilon: 1.0
# episode: 23   score: 14.0   memory length: 552   epsilon: 1.0
# episode: 24   score: 16.0   memory length: 569   epsilon: 1.0
# episode: 25   score: 14.0   memory length: 584   epsilon: 1.0
# episode: 26   score: 25.0   memory length: 610   epsilon: 1.0
# episode: 27   score: 29.0   memory length: 640   epsilon: 1.0
# episode: 28   score: 45.0   memory length: 686   epsilon: 1.0
# episode: 29   score: 75.0   memory length: 762   epsilon: 1.0
# episode: 30   score: 28.0   memory length: 791   epsilon: 1.0
# episode: 31   score: 25.0   memory length: 817   epsilon: 1.0
# episode: 32   score: 10.0   memory length: 828   epsilon: 1.0
# episode: 33   score: 42.0   memory length: 871   epsilon: 1.0
# episode: 34   score: 7.0   memory length: 879   epsilon: 1.0
# episode: 35   score: 14.0   memory length: 894   epsilon: 1.0
# episode: 36   score: 10.0   memory length: 905   epsilon: 1.0
# episode: 37   score: 33.0   memory length: 939   epsilon: 1.0
# episode: 38   score: 32.0   memory length: 972   epsilon: 1.0
# episode: 39   score: 52.0   memory length: 1025   epsilon: 0.9743224148844496
# episode: 40   score: 17.0   memory length: 1043   epsilon: 0.9569328906720129
# episode: 41   score: 35.0   memory length: 1079   epsilon: 0.9230793978373364
# episode: 42   score: 10.0   memory length: 1090   epsilon: 0.9129761418240965
# episode: 43   score: 24.0   memory length: 1115   epsilon: 0.8904235427767183
# episode: 44   score: 33.0   memory length: 1149   epsilon: 0.8606433826830369
# episode: 45   score: 32.0   memory length: 1182   epsilon: 0.8326919101044725
# episode: 46   score: 19.0   memory length: 1202   epsilon: 0.8161953381180397
# episode: 47   score: 11.0   memory length: 1214   epsilon: 0.8064546837933355
# episode: 48   score: 20.0   memory length: 1235   epsilon: 0.7896874231428072
# episode: 49   score: 24.0   memory length: 1260   epsilon: 0.7701803374578359
# episode: 50   score: 19.0   memory length: 1280   epsilon: 0.7549221906868242
# episode: 51   score: 11.0   memory length: 1292   epsilon: 0.745912783553375
# episode: 52   score: 42.0   memory length: 1335   epsilon: 0.7145029791340722
# episode: 53   score: 7.0   memory length: 1343   epsilon: 0.7088069214222238
# episode: 54   score: 36.0   memory length: 1380   epsilon: 0.6830476698153162
# episode: 55   score: 35.0   memory length: 1416   epsilon: 0.6588834367523301
# episode: 56   score: 93.0   memory length: 1510   epsilon: 0.5997420274569785
# episode: 57   score: 33.0   memory length: 1544   epsilon: 0.57968369259211
# episode: 58   score: 51.0   memory length: 1596   epsilon: 0.5502961455841082
# episode: 59   score: 13.0   memory length: 1610   epsilon: 0.5426418767371284
# episode: 60   score: 68.0   memory length: 1679   epsilon: 0.506444656987029
# episode: 61   score: 60.0   memory length: 1740   epsilon: 0.47646036099556505
# episode: 62   score: 29.0   memory length: 1770   epsilon: 0.46237188898344517
# episode: 63   score: 53.0   memory length: 1824   epsilon: 0.438054137254317
# episode: 64   score: 63.0   memory length: 1888   epsilon: 0.41088381354487985
# episode: 65   score: 58.0   memory length: 1947   epsilon: 0.3873315182940503
# episode: 66   score: 57.0   memory length: 2000   epsilon: 0.3654947603053141
# episode: 67   score: 31.0   memory length: 2000   epsilon: 0.35397841359256427
# episode: 68   score: 84.0   memory length: 2000   epsilon: 0.3251196941980479
# episode: 69   score: 134.0   memory length: 2000   epsilon: 0.2840430636776882
# episode: 70   score: 49.0   memory length: 2000   epsilon: 0.27018336082054484
# episode: 71   score: 41.0   memory length: 2000   epsilon: 0.25906521584796366
# episode: 72   score: 117.0   memory length: 2000   epsilon: 0.23021664244871493
# episode: 73   score: 121.0   memory length: 2000   epsilon: 0.20376344722313644
# episode: 74   score: 78.0   memory length: 2000   epsilon: 0.1882781182822748
# episode: 75   score: 154.0   memory length: 2000   epsilon: 0.16123173380420852
# episode: 76   score: 152.0   memory length: 2000   epsilon: 0.13834715185308472
# episode: 77   score: 500.0   memory length: 2000   epsilon: 0.08389079996522364
# episode: 78   score: 457.0   memory length: 2000   epsilon: 0.05305275521557503
# episode: 79   score: 495.0   memory length: 2000   epsilon: 0.03229907636978405
# episode: 80   score: 500.0   memory length: 2000   epsilon: 0.01958547984910047
# episode: 81   score: 444.0   memory length: 2000   epsilon: 0.012548056828667524
# episode: 82   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 83   score: 361.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 84   score: 285.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 85   score: 299.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 86   score: 328.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 87   score: 325.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 88   score: 295.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 89   score: 249.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 90   score: 377.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 91   score: 259.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 92   score: 353.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 93   score: 288.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 94   score: 284.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 95   score: 263.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 96   score: 345.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 97   score: 275.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 98   score: 310.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 99   score: 316.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 100   score: 270.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 101   score: 296.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 102   score: 274.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 103   score: 265.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 104   score: 353.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 105   score: 381.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 106   score: 315.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 107   score: 363.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 108   score: 348.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 109   score: 345.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 110   score: 498.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 111   score: 303.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 112   score: 312.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 113   score: 419.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 114   score: 400.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 115   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 116   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 117   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 118   score: 316.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 119   score: 158.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 120   score: 175.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 121   score: 100.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 122   score: 169.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 123   score: 287.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 124   score: 271.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 125   score: 273.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 126   score: 286.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 127   score: 270.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 128   score: 312.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 129   score: 343.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 130   score: 314.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 131   score: 359.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 132   score: 364.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 133   score: 327.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 134   score: 401.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 135   score: 328.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 136   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 137   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 138   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 139   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 140   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 141   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 142   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 143   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 144   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 145   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896

# %%
env = gym.make('CartPole-v1')
state_size = env.observation_space.shape[0]
action_size = env.action_space.n

# DQN 에이전트 생성
agent = DQNAgent(state_size, action_size)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 24)                120
# _________________________________________________________________
# dense_19 (Dense)             (None, 24)                600
# _________________________________________________________________
# dense_20 (Dense)             (None, 2)                 50
# =================================================================
# Total params: 770
# Trainable params: 770
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_21 (Dense)             (None, 24)                120
# _________________________________________________________________
# dense_22 (Dense)             (None, 24)                600
# _________________________________________________________________
# dense_23 (Dense)             (None, 2)                 50
# =================================================================
# Total params: 770
# Trainable params: 770
# Non-trainable params: 0
# _________________________________________________________________

# %%
agent.model.load_weights("cartpole_dqn.h5")

# %% [markdown]
# * 에러 발생시
# pip install h5py==2.10.0

# %%
pip install h5py==2.10.0
# Out:
# Requirement already satisfied: h5py==2.10.0 in c:\programdata\anaconda3\lib\site-packages (2.10.0)
# Requirement already satisfied: numpy>=1.7 in c:\programdata\anaconda3\lib\site-packages (from h5py==2.10.0) (1.19.2)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from h5py==2.10.0) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
model = agent.model

# %%
def render_policy_net(model, n_max_steps=200, seed=42):
    frames = []
    env = gym.make("CartPole-v1")
    env.seed(seed)
    np.random.seed(seed)
    obs = env.reset()
    for step in range(n_max_steps):
        frames.append(env.render(mode="rgb_array"))
        left_proba = model.predict(obs.reshape(1, -1))
        action = np.argmax(left_proba)
        obs, reward, done, info = env.step(action)
        if done:
            break
    env.close()
    return frames

# %%
frames = render_policy_net(model, 500)

# %%
plot_animation(frames)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img18f46defe14d4a7bb4a0b620d9bd92ee">
#   <div class="anim-controls">
#     <input id="_anim_slider18f46defe14d4a7bb4a0b620d9bd92ee" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim18f46defe14d4a7bb4a0b620d9bd92ee.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" onclick="anim18f46defe14d4a7bb4a0b620d9bd92ee.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" onclick="anim18f46defe14d4a7bb4a0b620d9bd92ee.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" onclick="anim18f46defe14d4a7bb4a0b620d9bd92ee.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" onclick="anim18f46defe14d4a7bb4a0b620d9bd92ee.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" onclick="anim18f46defe14d4a7bb4a0b620d9bd92ee.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" onclick="anim18f46defe14d4a7bb4a0b620d9bd92ee.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" onclick="anim18f46defe14d4a7bb4a0b620d9bd92ee.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" onclick="anim18f46defe14d4a7bb4a0b620d9bd92ee.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" onclick="anim18f46defe14d4a7bb4a0b620d9bd92ee.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" action="#n" name="_anim_loop_select18f46defe14d4a7bb4a0b620d9bd92ee"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_18f46defe14d4a7bb4a0b620d9bd92ee"
#              checked>
#       <label for="_anim_radio1_18f46defe14d4a7bb4a0b620d9bd92ee">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_18f46defe14d4a7bb4a0b620d9bd92ee"
#              >
#       <label for="_anim_radio2_18f46defe14d4a7bb4a0b620d9bd92ee">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_18f46defe14d4a7bb4a0b620d9bd92ee"
#              >
#       <label for="_anim_radio3_18f46defe14d4a7bb4a0b620d9bd92ee">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img18f46defe14d4a7bb4a0b620d9bd92ee";
#     var slider_id = "_anim_slider18f46defe14d4a7bb4a0b620d9bd92ee";
#     var loop_select_id = "_anim_loop_select18f46defe14d4a7bb4a0b620d9bd92ee";
#     var frames = new Array(500);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjMuMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8vihELAAAACXBIWXMAAAsT\
# AAALEwEAmpwYAAAHPklEQVR4nO3dzWtddR7H8e9JbpO0vTbxToh3EHXAB4QZUVy50I0rkS66dzF/\
# RaH/gWDXhf4Ps8l6hln5QFFbZwTBqAMWNY3Shj7EtknTHBczDJQM2GTMOf3cvF67++PenE8W4Z2b\
# 3Js0bdsWAKSZ6nsAAOyHgAEQScAAiCRgAEQSMAAiCRgAkQQMgEgCBkAkAQMgkoABEEnAAIgkYABE\
# EjAAIgkYAJEEDIBIAgZAJAEDIJKAA
